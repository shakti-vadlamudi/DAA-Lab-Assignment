# %%
import time
import matplotlib.pyplot as plt

def iterative_sum(N):
    result = 0
    for i in range(1, N + 1):
        result += i
    return result

def recursive_sum(N):
    if N == 0:
        return 0
    else:
        return N + recursive_sum(N - 1)

def measure_time(algorithm, values):
    times = []
    for value in values:
        start_time = time.time()
        algorithm(value)
        end_time = time.time()
        times.append(end_time - start_time)
    return times

N_values = list(range(1, 1001, 100))

iterative_times = measure_time(iterative_sum, N_values)
recursive_times = measure_time(recursive_sum, N_values)

plt.plot(N_values, iterative_times, label='Iterative')
plt.plot(N_values, recursive_times, label='Recursive')
plt.xlabel('Value of N')
plt.ylabel('Time taken (seconds)')
plt.title('Time taken for sum of first N natural numbers')
plt.legend()
plt.show()

# %% [markdown]
# 2nd question

# %%
import random
import time
import matplotlib.pyplot as plt

def linear_search(arr, key):
    for i in range(len(arr)):
        if arr[i] == key:
            return i
    return -1

def binary_search(arr, key):
    low = 0
    high = len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid + 1
        else:
            high = mid - 1
    return -1

arr = [random.randint(1, 1000) for _ in range(10000)]
arr.sort()
def measure_time(search_algorithm, keys):
    times = []
    for key in keys:
        start_time = time.time()
        search_algorithm(arr, key)
        end_time = time.time()
        times.append(end_time - start_time)
    return times

search_keys = [random.randint(1, 1000) for _ in range(5)]

linear_times = measure_time(linear_search, search_keys)


binary_times = measure_time(binary_search, search_keys)

plt.plot(search_keys, linear_times, label='Linear Search')
plt.plot(search_keys, binary_times, label='Binary Search')
plt.xlabel('Search Key')
plt.ylabel('Time taken (seconds)')
plt.title('Time taken for linear and binary search')
plt.legend()
plt.show()

# %% [markdown]
# 3rd question

# %%
def string_to_integer_with_commas(s):


  if len(s) <= 3:
    return s

  else:

    return string_to_integer_with_commas(s[:-3]) + ',' + s[-3:]

# Example usage
number_string = "1234567890"
integer_with_commas = string_to_integer_with_commas(number_string)
print(integer_with_commas)
# Out:
# 1,234,567,890

# %% [markdown]
# 4th question

# %%
def reverse_string(s):

  if len(s) == 0:
    return s  # Empty string is its own reverse

  else:
    # Return the last character + the reversed remaining string
    return s[-1] + reverse_string(s[:-1])

# Example usage
string = "pots&pans"
reversed_string = reverse_string(string)
print(reversed_string)  # Output: snap&stop
# Out:
# snap&stop

# %% [markdown]
# question 5

# %%
def is_palindrome(s):
  """
  Checks if a string is a palindrome (reads the same backward as forward) recursively.

  Args:
      s: The string to check.

  Returns:
      True if the string is a palindrome, False otherwise.
  """

  # Base cases
  if len(s) <= 1:
    return True  # Empty string or single character is a palindrome

  # Check if the first and last characters are the same
  if s[0] != s[-1]:
    return False

  # Recursively check the remaining substring
  return is_palindrome(s[1:-1])

# Example usage
strings = ["racecar", "gohangasalamiimalasagnahog", "apple", "madam"]
for string in strings:
  if is_palindrome(string):
    print(f"{string} is a palindrome")
  else:
    print(f"{string} is not a palindrome")
# Out:
# racecar is a palindrome
# gohangasalamiimalasagnahog is a palindrome
# apple is not a palindrome
# madam is a palindrome
